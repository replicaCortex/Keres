# %%
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# # Упражнение 1

# %%
import numpy as np

_ = [1, 10 , 1000]

def Q1(x):
    return np.log(np.exp(1/(np.sin(x)+1)/((5/4) + (1/x**15)))) / np.log(1+x**2)

print(Q1(np.array(_)))
# Out:
# [0.3481987  0.38015631 0.        ]

# %%
x = np.arange(-10, 10+1, 0.1)

def Q2(x):
	return x * x - x - 6

plt.plot(x, Q2(x))
plt.grid(True)
plt.show()

# %% [markdown]
# # Упражнение 2

# %%
def Q3(x):
	return np.log((x**2 + 1) * np.exp(-(np.abs(x)/10))) / np.log(1 + np.tan(1/(1 + np.sin(x)**2)))

plt.plot(x, Q3(x))
plt.grid(True)
plt.show()

# %% [markdown]
# # Упражнение 3

# %%
plt.pie([90, 10, 10, 10], labels=('В комментариях', 'В Ираке', 'В Сирии', 'В Афганистане'))
plt.title('Где ведутся самые ожесточенные бои')
# Out:
# Text(0.5, 1.0, 'Где ведутся самые ожесточенные бои')

# %% [markdown]
# # Упражнение 4

# %%
x = [1, 2, 3, 4, 5]
y = [0.99, 0.49, 0.35, 0.253, 0.18]
plt.errorbar(x, y, xerr=0.05, yerr=0.1)
plt.grid()
plt.show()

# %%
x = np.arange(0, 10, 0.01)
plt.plot(x, x**2, label=r'$f = x^2$')
plt.scatter(x, x**2 + np.random.randn(len(x))*x, s=0.3)
plt.fill_between(x, 1.3*x**2, 0.7*x**2, alpha=0.3)
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
x=[1, 2, 3, 4, 5, 6]
y=[1, 1.42, 1.76, 2, 2.24, 2.5]
p,v=np.polyfit(x, y, deg=1, cov=True)
print(f"p = {p}\nv = {v}")
# Out:
# p = [0.29142857 0.8       ]
# v = [[ 0.00029878 -0.00104571]
#  [-0.00104571  0.00453143]]

# %%
p_f = np.poly1d(p)
p_f(0.5)
p_f([1, 2, 3])
# Out:
# array([1.09142857, 1.38285714, 1.67428571])

# %% [markdown]
# # Упражнение 5

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

x = np.array([1, 2, 3, 4, 5])
y = np.array([2.1, 3.7, 5.6, 7.2, 8.9])
y_err = np.array([0.2, 0.3, 0.3, 0.4, 0.5])  

def linear(x, a, b):
    return a * x + b

def quadratic(x, a, b, c):
    return a * x**2 + b * x + c

popt_linear, _ = curve_fit(linear, x, y, sigma=y_err)
popt_quadratic, _ = curve_fit(quadratic, x, y, sigma=y_err)

x_fit = np.linspace(min(x), max(x), 100)
y_fit_linear = linear(x_fit, *popt_linear)
y_fit_quadratic = quadratic(x_fit, *popt_quadratic)

plt.figure(figsize=(10, 6))
plt.errorbar(x, y, yerr=y_err, fmt='o', label='Данные с погрешностями')
plt.plot(x_fit, y_fit_linear, 'r-', linewidth = 2, label='Линейная аппроксимация')
plt.plot(x_fit, y_fit_quadratic, 'g-', label='Квадратичная аппроксимация')

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Аппроксимация данных')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Упражнение 6

# %%
a = 0.5
b = 3
n = 50  

def weierstrass(x, a, b, n):
    return sum(a**k * np.cos(b**k * np.pi * x) for k in range(n))

x = np.linspace(-2, 2, 1000)

y = [weierstrass(xi, a, b, n) for xi in x]

plt.plot(x, y, 'b-', linewidth=0.5)
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()
